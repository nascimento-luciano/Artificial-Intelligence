# %% [markdown]
# <a href="https://colab.research.google.com/github/nascimento-luciano/Artificial-Intelligence/blob/master/Duas_Ou_Mais_Figuras_Mesmo_Grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                                    #importa a biblioteca numpy com o apelido de np
import matplotlib.pyplot as plt                       #importa a biblioteca matplotlib com o apelido de plt

plt.rcParams.update({'font.size':14})

x = np.linspace(-3,5,1000)                            #cria o vetor [-3, 5, 1000] e guarda na variável "x"
y = x*x-2*x+4                                         #calcula x.x-2.x+4 e guarda na variável "y"        
z = x**3-3*x+10                                       #usamos uma nova variável para a segunda função.lembre: em python x**3 é x ao cubo


plt.subplot(2,1,1)                                    #2 linhas; 1 coluna, gráfico 1
plt.plot(x,y,'--k',linewidth=2)
plt.ylabel('parábola')
plt.subplot(2,1,2)                                    #2 linhas; 1 coluna, gráfico 2
plt.plot(x,z,'r', linewidth=2)
plt.ylabel('função cúbica')
plt.xlabel('x')                                       #os plt.grid() foram tirados apenas por simplicidade
# Out:
# Text(0.5, 0, 'x')
