# %% [markdown]
# <a href="https://colab.research.google.com/github/nascimento-luciano/Artificial-Intelligence/blob/master/MeuPrimeiroGrafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                                     #importa a biblioteca numpy com o apelido de np
import matplotlib.pyplot as plt                        #importa a biblioteca matplotlib com o apelido de plt

x = np.array([-3, -2, -1, 0, 1, 2, 3, 4, 5])           #cria o vetor [-3, -2, -1, 0, 1, 2, 3, 4, 5] e guarda na variável "x"
y = x*x-2*x+4                                          #calcula x.x-2.x+4 e guarda na variável "y"        
plt.plot(x,y)                                          #faz o gráfico de y por x, usando as configurações padrão da função "plot"
